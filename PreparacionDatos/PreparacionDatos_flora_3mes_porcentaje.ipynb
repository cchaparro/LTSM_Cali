# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn import datasets
from numpy import array
from pandas import DataFrame
from pandas import concat
from keras.models import model_from_json
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

#Ruta del raiz de directorio.
Ruta="../"

# %%
#Datos La información sobre los trimetres de la estacion de la flora

FloraTotal_3mes = pd.read_excel(Ruta+'PreparacionDatos/FloraTotal_3mes_3V_mas_4.xlsx',sheet_name='FloraTotal', header=0)

FloraTotal_3mes
# Out:
#     Motos_vehiculos_particulares    Lluvia   Poblacion
# 0                     348066.000  0.939613  2244668.00
# 1                     348066.000  0.382813  2244668.00
# 2                     348066.000  0.263172  2244668.00
# 3                     348066.000  0.572834  2244668.00
# 4                     391327.000  0.190382  2269653.00
# 5                     391327.000  0.413592  2269653.00
# 6                     391327.000  0.408934  2269653.00
# 7                     391327.000  0.595508  2269653.00
# 8                     438769.000  0.060729  2294653.00
# 9                     438769.000  0.426957  2294653.00
# 10                    438769.000  0.107707  2294653.00
# 11                    438769.000  0.419806  2294653.00
# 12                    484119.000  0.185106  2319684.00
# 13                    484119.000  0.276111  2319684.00
# 14                    484119.000  0.134173  2319684.00
# 15                    484119.000  0.472869  2319684.00
# ...

# %%
#Cargo el modelo antes generado.
json_file = open('../Modelamiento/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# Cargo el nuevo modelo
loaded_model.load_weights("../Modelamiento/LTSM_Cali_3meses.h5")
loaded_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_3 (LSTM)                (None, 50)                10800
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...
# Total params: 10,851
# Trainable params: 10,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
values = FloraTotal_3mes.values

# %%
values = values.reshape((values.shape[0], 1, values.shape[1]))

# %%
values.shape
# Out:
# (36, 1, 3)

# %%
yhat = loaded_model.predict(values, verbose=0)
print(yhat)
# Out:
# [[1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.0459689]
#  [1.6356308]
#  [1.6356308]
#  [1.6356308]
#  [1.6356308]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [1.7393099]
#  [3.508834 ]
#  [3.508834 ]
#  [3.508834 ]
#  [3.2241385]]

# %%
df = pd.DataFrame({ 'Motos_vehiculos_particulares':    [348066,348066],
                    'Lluvia': [148.0,939612567424774,148.0,382813453674316],
                    'Poblacion': [2244668,2244668]

                   })

# %%
values = df.values
values = values.reshape((values.shape[0], 1, values.shape[1]))
yhat = loaded_model.predict(values, verbose=0)
print(yhat)
