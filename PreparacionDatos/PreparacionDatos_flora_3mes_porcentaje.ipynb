# %%
import numpy as np
import pandas as pd
from scipy import stats
from datetime import datetime

#Ruta del raiz de directorio.
Ruta="../"

# %%
#Datos La información sobre los trimetres de la estacion de la flora

FloraTotal_3mes = pd.read_excel(Ruta+'PreparacionDatos/FloraTotal_3mes.xlsx',sheet_name='FloraTotal', header=0)


FloraTotal_3mes.head(19)
# Out:
#                   Fecha          CO     DirVien              Fecha.1  H2S  \
# 0   2010-06-18 00:00:00  391.467102  176.100006  2010-06-18 00:00:00    0
# 1   2010-06-18 00:00:00  708.846497  149.000000  2010-06-18 00:00:00    0
# 2   2010-06-18 00:00:00  683.904480  144.000000  2010-06-18 00:00:00    0
# 3   2010-06-18 00:00:00  841.206421  197.199997  2010-06-18 00:00:00    0
# 4   2010-06-19 00:00:00  681.828613   29.299999  2010-06-19 00:00:00    0
# 5   2010-06-19 00:00:00  634.866394    8.000000  2010-06-19 00:00:00    0
# 6   2010-06-19 00:00:00  668.423523  347.299988  2010-06-19 00:00:00    0
# 7   2010-06-19 00:00:00  577.201599   34.799999  2010-06-19 00:00:00    0
# 8   2010-06-19 00:00:00  724.085388  343.399994  2010-06-19 00:00:00    0
# 9   2010-06-19 00:00:00  971.997925   22.400000  2010-06-19 00:00:00    0
# 10  2010-06-19 00:00:00  576.613403   26.700001  2010-06-19 00:00:00    0
# 11  2010-06-19 00:00:00  531.930908   42.599998  2010-06-19 00:00:00    0
# ...

# %%
#remplzo por el 95 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.95
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] * 0.95

FloraTotal_3mes.to_excel("FloraTotal_3mes_95.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.

# %%
#remplzo por el 90 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.9
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] * 0.9

FloraTotal_3mes.to_excel("FloraTotal_3mes_90.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.

# %%
#remplzo por el 85 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.85
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] *0.85

FloraTotal_3mes.to_excel("FloraTotal_3mes_85.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.

# %%
#remplzo por el 80 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.8
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] * 0.8

FloraTotal_3mes.to_excel("FloraTotal_3mes_80.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.

# %%
#remplzo por el 90 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.75
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] * 0.75

FloraTotal_3mes.to_excel("FloraTotal_3mes_75.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.

# %%
#remplzo por el 90 % la colmunas de PM y Motos_vehiculos_particulares
FloraTotal_3mes['Motos_vehiculos_particulares'] = FloraTotal_3mes['Motos_vehiculos_particulares'] * 0.7
FloraTotal_3mes['PM10'] = FloraTotal_3mes['PM10'] * 0.7

FloraTotal_3mes.to_excel("FloraTotal_3mes_70.xlsx", sheet_name='FloraTotal',encoding='UTF-8') #Se crea el archivo definitivo.
